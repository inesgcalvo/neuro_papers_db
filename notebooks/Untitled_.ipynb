# %%
import pandas as pd

# %%
articles_info = pd.read_csv('../data/journal_info.csv')
articles_info[9:25]
# Out:
#                          journal_name  num_articles  num_pages
# 9                      Brain Research          8067        807
# 10       Reviews in the Neurosciences           739         74
# 11       Frontiers in Neural Circuits          1521        153
# 12      Annual Review of Neuroscience           331         34
# 13              Biological Psychology          2218        222
# 14        Journal of Physiology Paris           273         28
# 15  Frontiers in Systems Neuroscience          1669        167
# 16  Current Protocols in Neuroscience           196         20
# 17                 Biomedical Reports          1657        166
# 18                 Brain Multiphysics             8          1
# 19                Nature Neuroscience          3722        373
# 20      Translational Stroke Research          1199        120
# 21   Advances in Cognitive Psychology           245         25
# 22                  AIMS Neuroscience           157         16
# 23          Frontiers in Neuroscience         13102       1311
# 24                              eLife         15486       1549

# %%
prueba = 'https://pubmed.ncbi.nlm.nih.gov/?term=%28%28%22Stroke%2'
print(prueba[47:53])
# Out:
# Stroke

# %%
articles_info['num_pages'].sum()
# Out:
# 22305

# %%
articles_info = pd.read_csv('../data/journal_info.csv')
articles_info

i = 3500
j = 4000
maximo = len(url_list)/12
errors = []

for num in range(11, maximo):
    if (num+1) < 11:
        name = f'00{num}'
    elif (num+1) < 101:
        name = f'0{num}'
    else:
        name = f'{num}'
    
    try:
        
        i = j
        j += 500
    except:
        errors.append(name, i, j)
        i = j
        j += 500
        continue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 6
#       4 i = 3500
#       5 j = 4000
# ----> 6 maximo = len(url_list)/12
#       8 for num in range(11, maximo):
#       9     if (num+1) < 11:
#
# NameError: name 'url_list' is not defined

# %%
lista = '''
         00  index                249 non-null    int32  
         01  Country              249 non-null    object 
         02  Official_state_name  249 non-null    object 
         03  Sovereignty          249 non-null    object 
         04  Alpha_2_code         249 non-null    object 
         05  Alpha_3_code         249 non-null    object 
         06  mln_2010             249 non-null    float64
         07  mln_2011             249 non-null    float64
         08  mln_2012             249 non-null    float64
         09  mln_2013             249 non-null    float64
         10  mln_2014             249 non-null    float64
         11  mln_2015             249 non-null    float64
         12  mln_2016             249 non-null    float64
         13  mln_2017             249 non-null    float64
         14  mln_2018             249 non-null    float64
         15  mln_2019             249 non-null    float64
         16  mln_2020             249 non-null    float64
         17  mln_2021             249 non-null    float64
         18  mln_2022             249 non-null    float64
         19  gdp_2010             249 non-null    float64
         20  gdp_2011             249 non-null    float64
         21  gdp_2012             249 non-null    float64
         22  gdp_2013             249 non-null    float64
         23  gdp_2014             249 non-null    float64
         24  gdp_2015             249 non-null    float64
         25  gdp_2016             249 non-null    float64
         26  gdp_2017             249 non-null    float64
         27  gdp_2018             249 non-null    float64
         28  gdp_2019             249 non-null    float64
         29  gdp_2020             249 non-null    float64
         30  gdp_2021             249 non-null    float64
         31  gdp_2022             249 non-null    float64
         32  tot_2010             249 non-null    float64
         33  tot_2011             249 non-null    float64
         34  tot_2012             249 non-null    float64
         35  tot_2013             249 non-null    float64
         36  tot_2014             249 non-null    float64
         37  tot_2015             249 non-null    float64
         38  tot_2016             249 non-null    float64
         39  tot_2017             249 non-null    float64
         40  tot_2018             249 non-null    float64
         41  tot_2019             249 non-null    float64
         42  tot_2020             249 non-null    float64
         43  tot_2021             249 non-null    float64
         44  wom_2010             249 non-null    float64
         45  wom_2011             249 non-null    float64
         46  wom_2012             249 non-null    float64
         47  wom_2013             249 non-null    float64
         48  wom_2014             249 non-null    float64
         49  wom_2015             249 non-null    float64
         50  wom_2016             249 non-null    float64
         51  wom_2017             249 non-null    float64
         52  wom_2018             249 non-null    float64
         53  wom_2019             249 non-null    float64
         54  wom_2020             249 non-null    float64
         55  wom_2021             249 non-null    float64
         '''

# %%
columnas = lista.split('\n')
columnas = [col.strip() for col in columnas]
# columnas = [col.split('') for col in columnas]
columnas = [col.split(' ')[2] for col in columnas if col != '']
columnas
# Out:
# ['index',
#  'Country',
#  'Official_state_name',
#  'Sovereignty',
#  'Alpha_2_code',
#  'Alpha_3_code',
#  'mln_2010',
#  'mln_2011',
#  'mln_2012',
#  'mln_2013',
#  'mln_2014',
#  'mln_2015',
#  'mln_2016',
#  'mln_2017',
#  'mln_2018',
#  'mln_2019',
#  'mln_2020',
#  'mln_2021',
#  'mln_2022',
#  'gdp_2010',
#  'gdp_2011',
#  'gdp_2012',
#  'gdp_2013',
#  'gdp_2014',
#  'gdp_2015',
#  'gdp_2016',
#  'gdp_2017',
#  'gdp_2018',
#  'gdp_2019',
#  'gdp_2020',
#  'gdp_2021',
#  'gdp_2022',
#  'tot_2010',
#  'tot_2011',
#  'tot_2012',
#  'tot_2013',
#  'tot_2014',
#  'tot_2015',
#  'tot_2016',
#  'tot_2017',
#  'tot_2018',
#  'tot_2019',
#  'tot_2020',
#  'tot_2021',
#  'wom_2010',
#  'wom_2011',
#  'wom_2012',
#  'wom_2013',
#  'wom_2014',
#  'wom_2015',
#  'wom_2016',
#  'wom_2017',
#  'wom_2018',
#  'wom_2019',
#  'wom_2020',
#  'wom_2021']

# %%
info = {}
for col in articles.columns:
    info[col]= {'% NaN': np.around(articles[col].isna().sum() / len(articles) * 100),
                'uniques': len(articles['ID'].unique()),
                'type': articles['ID'].dtype}
info
